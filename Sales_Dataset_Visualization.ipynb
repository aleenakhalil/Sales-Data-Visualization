# %% [markdown]
# <a href="https://colab.research.google.com/github/aleenakhalil/Sales-Data-Visualization/blob/main/Sales_Dataset_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Visualizing Sales Data (Kaggle Sales Dataset)

# %% [markdown]
# Step 1: Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Step 2: Loading the Dataset

# %%
sales_df = pd.read_csv('sales_data.csv', encoding='ISO-8859-1')

# %% [markdown]
# Step 3: Previewing the Dataset

# %% [markdown]
# Columns

# %%
sales_df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# First & Last 5 Rows

# %%
sales_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
sales_df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %% [markdown]
# Statistical Summary

# %%
sales_df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %% [markdown]
# Basic Information (data types, non-null count etc.)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# Identifying Missing Values

# %%
sales_df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %% [markdown]
# Converting ORDERDATE to Datetime

# %%
sales_df['ORDERDATE'] = pd.to_datetime(sales_df['ORDERDATE'])

# %% [markdown]
# Step 4: Handling Missing Data

# %% [markdown]
# Instead of replacing missing values in columns like TERRITORY, STATE, and POSTALCODE with methods such as mean or median (which could introduce inaccuracies), placeholder values such as 'Unknown' or '00000' have been assigned.

# %% [markdown]
# Since ADDRESSLINE2 is usually optional, it can be safely dropped or left as is without significantly affecting the dataset.

# %%
sales_df['STATE'] = sales_df['STATE'].fillna('Unknown')
sales_df['POSTALCODE'] = sales_df['POSTALCODE'].fillna('00000')
sales_df['TERRITORY'] = sales_df['TERRITORY'].fillna('Unknown')

# %% [markdown]
# Step 4: Visualizations

# %%
sales_df['Month'] = sales_df['ORDERDATE'].dt.to_period('M')
monthly_sales = sales_df.groupby('Month')['SALES'].sum()

plt.figure(figsize=(8,6))
monthly_sales.plot(kind='line', color='teal', linewidth=2)
plt.title('Total Sales Over Time (Monthly)', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
country_sales = sales_df.groupby('COUNTRY')['SALES'].sum().sort_values(ascending=False)
palette = sns.color_palette('husl', n_colors=len(country_sales))
plt.figure(figsize=(12, 6))
sns.barplot(x=country_sales.index, y=country_sales.values, palette=palette)
plt.title('Sales by Country', fontsize=16)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
product_line_sales = sales_df.groupby('PRODUCTLINE')['SALES'].sum().sort_values(ascending=False)
plt.figure(figsize=(10,6))
sns.barplot(x=product_line_sales.index, y=product_line_sales.values, palette='viridis')
plt.title('Sales by Product Line', fontsize=16)
plt.xlabel('Product Line', fontsize=14)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-32-6c0223b9cdb4>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_line_sales.index, y=product_line_sales.values, palette='viridis')

# %%
deal_size_sales = sales_df.groupby('DEALSIZE')['SALES'].sum()

plt.figure(figsize=(8,6))
sns.barplot(x=deal_size_sales.index, y=deal_size_sales.values, palette='Blues')
plt.title('Sales by Deal Size', fontsize=16)
plt.xlabel('Deal Size', fontsize=14)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-25c0ec8915d6>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=deal_size_sales.index, y=deal_size_sales.values, palette='Blues')

# %%
corr = sales_df[['SALES', 'QUANTITYORDERED', 'PRICEEACH', 'MSRP']].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='BuGn', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='QUANTITYORDERED', y='SALES', data=sales_df, color='green', alpha=0.6)
plt.title('Sales vs. Quantity Ordered', fontsize=16)
plt.xlabel('Quantity Ordered', fontsize=14)
plt.ylabel('Sales ($)', fontsize=14)
plt.tight_layout()
plt.show()

# %%
category_deals_pivot = sales_df.groupby(['PRODUCTLINE', 'DEALSIZE'])['SALES'].sum().unstack().fillna(0)
category_deals_pivot.plot(kind='bar', stacked=True, figsize=(8, 6), colormap='Set2')
plt.title('Product Category vs Deal Size (Stacked)', fontsize=16)
plt.xlabel('Product Category', fontsize=14)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title="Deal Size", title_fontsize='13')
plt.tight_layout()
plt.show()
